# %%
import pandas as pd
from helper_functions import get_master_df, save_df

# %%
df = get_master_df()
if "Unnamed: 0" in df.columns:
    df.drop("Unnamed: 0", axis=1, inplace=True)
df
# Out:
#       mp_team0  fg_team0  fga_team0  fg%_team0  3p_team0  3pa_team0  \
# 0        240.0      47.0       97.0      0.485      15.0       41.0
# 1        240.0      36.0       88.0      0.409       8.0       32.0
# 2        240.0      33.0       83.0      0.398      12.0       45.0
# 3        240.0      29.0       73.0      0.397       9.0       30.0
# 4        240.0      48.0       94.0      0.511       9.0       18.0
# ...        ...       ...        ...        ...       ...        ...
# 8463     240.0      41.0       95.0      0.432      13.0       37.0
# 8464     240.0      40.0       90.0      0.444      10.0       36.0
# 8465     240.0      50.0       88.0      0.568      11.0       29.0
# 8466     240.0      45.0       84.0      0.536      17.0       35.0
# 8467     240.0      45.0       86.0      0.523      13.0       31.0
#
#       3p%_team0  ft_team0  fta_team0  ft%_team0  ...  blk%_team1  tov%_team1  \
# 0         0.366      13.0       19.0      0.684  ...        16.1        16.0
# 1         0.250      19.0       25.0      0.760  ...         7.1        15.3
# 2         0.267      27.0       29.0      0.931  ...        10.5        15.5
# 3         0.300      23.0       29.0      0.793  ...         7.0         7.3
# 4         0.500      12.0       15.0      0.800  ...         5.3        13.6
# ...         ...       ...        ...        ...  ...         ...         ...
# 8463      0.351       7.0       18.0      0.389  ...        20.7        19.7
# 8464      0.278      17.0       18.0      0.944  ...        13.0         9.0
# 8465      0.379      11.0       18.0      0.611  ...         1.7        12.7
# 8466      0.486      12.0       14.0      0.857  ...        10.2         8.4
# 8467      0.419      13.0       15.0      0.867  ...         7.3        16.3
#
#       ortg_team1  drtg_team1  team1  winner  season        date  \
# 0          118.6       119.6    GSW     HOU    2018  2017-10-17
# 1          102.7        99.7    CLE     CLE    2018  2017-10-17
# 2          103.9       109.1    SAC     HOU    2018  2017-10-18
# 3          103.6        91.4    DET     DET    2018  2017-10-18
# 4          112.6       118.7    DAL     ATL    2018  2017-10-18
# ...          ...         ...    ...     ...     ...         ...
# 8463       116.7       103.5    PHO     PHO    2024  2024-03-20
# 8464       119.9       107.8    OKC     OKC    2024  2024-03-20
# 8465       100.7       119.3    DET     IND    2024  2024-03-20
# 8466       131.1       127.9    BOS     BOS    2024  2024-03-20
# 8467       108.9       122.6    POR     LAC    2024  2024-03-20
#
#       team0_encoded  team1_encoded
# 0                29             21
# 1                 2              6
# 2                29             23
# 3                13              8
# 4                12             27
# ...             ...            ...
# 8463              5             24
# 8464             18             16
# 8465              7              8
# 8466             10              2
# 8467             22             17
#
# [8468 rows x 71 columns]

# %%
team_encoding = { 
    # ATLANTIC
    "TOR": 1,
    "BOS": 2,
    "NYK": 3, 
    "BRK": 4,
    "PHI": 5,

    # CENTRAL
    "CLE": 6,
    "IND": 7,
    "DET": 8,
    "CHI": 9,
    "MIL": 10,

    # SOUTHEAST
    "MIA": 11,
    "ATL": 12,
    "CHO": 13,
    "WAS": 14,
    "ORL": 15,

    # NORTHWEST
    "OKC": 16,
    "POR": 17,
    "UTA": 18,
    "DEN": 19,
    "MIN": 20,

    # PACIFIC
    "GSW": 21, 
    "LAC": 22,
    "SAC": 23,
    "PHO": 24,
    "LAL": 25,

    # SOUTH WEST
    "SAS": 26,
    "DAL": 27,
    "MEM": 28,
    "HOU": 29,
    "NOP": 30
}

# %%
unique_stats = [col.split("_")[0] + "_prev_game" for col in df.columns if "_team0" in col]
stats = [col.split("_")[0] for col in df.columns if "_team0" in col]
teams = team_encoding.keys()

# %%
def initialize_prev_game_stats():
    prev_game = {}
    for team in teams:
        team_prev_game = {}
        for stat in unique_stats:
            team_prev_game[stat] = 0
        prev_game[team] = team_prev_game
        prev_game[team]["games_played"] = 0
    
    return prev_game

# %%
prev_game = initialize_prev_game_stats()
current_season = None

first_game_indices = set()
    
for index, row in df.iterrows():
    team0 = row['team0']
    team1 = row['team1']
    game_season = row['season']

    if game_season != current_season:
        prev_game = initialize_prev_game_stats()
        current_season = game_season

    games_played_team0 = prev_game[team0]["games_played"]
    games_played_team1 = prev_game[team1]["games_played"]

    if games_played_team0 == 0:
        first_game_indices.add(index)
    
    if games_played_team1 == 0:
        first_game_indices.add(index)

    if games_played_team0 > 0:
        for stat in unique_stats:
            prev_game_team0 = prev_game[team0][stat]
            df.at[index, f"{stat}_team0"] = prev_game_team0
    
    if games_played_team1 > 0:
        for stat in unique_stats:
            prev_avg_team1 = prev_game[team1][stat]
            df.at[index, f"{stat}_team1"] = prev_avg_team1
    
    for stat in stats:
        prev_game[team0][f"{stat}_prev_game"] = row[f"{stat}_team0"]
        prev_game[team1][f"{stat}_prev_game"] = row[f"{stat}_team1"]

    prev_game[team0]['games_played'] += 1
    prev_game[team1]['games_played'] += 1

    if index % 100 == 0:
         print(f"{index} / {len(df)}")
# Out:
# 0 / 8468
# 100 / 8468
# 200 / 8468
# 300 / 8468
# 400 / 8468
# 500 / 8468
# 600 / 8468
# 700 / 8468
# 800 / 8468
# 900 / 8468
# 1000 / 8468
# 1100 / 8468
# 1200 / 8468
# 1300 / 8468
# 1400 / 8468
# 1500 / 8468
# 1600 / 8468
# 1700 / 8468
# 1800 / 8468
# 1900 / 8468
# 2000 / 8468
# 2100 / 8468
# 2200 / 8468
# 2300 / 8468
# 2400 / 8468
# 2500 / 8468
# 2600 / 8468
# 2700 / 8468
# 2800 / 8468
# 2900 / 8468
# 3000 / 8468
# 3100 / 8468
# 3200 / 8468
# 3300 / 8468
# 3400 / 8468
# 3500 / 8468
# 3600 / 8468
# 3700 / 8468
# 3800 / 8468
# 3900 / 8468
# 4000 / 8468
# 4100 / 8468
# 4200 / 8468
# 4300 / 8468
# 4400 / 8468
# 4500 / 8468
# 4600 / 8468
# 4700 / 8468
# 4800 / 8468
# 4900 / 8468
# 5000 / 8468
# 5100 / 8468
# 5200 / 8468
# 5300 / 8468
# 5400 / 8468
# 5500 / 8468
# 5600 / 8468
# 5700 / 8468
# 5800 / 8468
# 5900 / 8468
# 6000 / 8468
# 6100 / 8468
# 6200 / 8468
# 6300 / 8468
# 6400 / 8468
# 6500 / 8468
# 6600 / 8468
# 6700 / 8468
# 6800 / 8468
# 6900 / 8468
# 7000 / 8468
# 7100 / 8468
# 7200 / 8468
# 7300 / 8468
# 7400 / 8468
# 7500 / 8468
# 7600 / 8468
# 7700 / 8468
# 7800 / 8468
# 7900 / 8468
# 8000 / 8468
# 8100 / 8468
# 8200 / 8468
# 8300 / 8468
# 8400 / 8468

# %%
first_game_indices

df = df.drop(first_game_indices)

# %%
df
# Out:
#       mp_team0  fg_team0  fga_team0  fg%_team0  3p_team0  3pa_team0  \
# 16       240.0      37.0       87.0      0.425      10.0       23.0
# 17       240.0      46.0       95.0      0.484       9.0       19.0
# 18       240.0      45.0       89.0      0.506      18.0       33.0
# 19       240.0      35.0       84.0      0.417      10.0       29.0
# 20       240.0      43.0       87.0      0.494      10.0       23.0
# ...        ...       ...        ...        ...       ...        ...
# 8463     240.0      41.0       95.0      0.432      13.0       37.0
# 8464     240.0      40.0       90.0      0.444      10.0       36.0
# 8465     240.0      50.0       88.0      0.568      11.0       29.0
# 8466     240.0      45.0       84.0      0.536      17.0       35.0
# 8467     240.0      45.0       86.0      0.523      13.0       31.0
#
#       3p%_team0  ft_team0  fta_team0  ft%_team0  ...  ftr_prev_game_team1  \
# 16        0.435       9.0       13.0      0.692  ...                0.244
# 17        0.474      13.0       17.0      0.765  ...                0.314
# 18        0.545      13.0       15.0      0.867  ...                0.340
# 19        0.345      22.0       32.0      0.688  ...                0.204
# 20        0.435      15.0       20.0      0.750  ...                0.392
# ...         ...       ...        ...        ...  ...                  ...
# 8463      0.351       7.0       18.0      0.389  ...                0.172
# 8464      0.278      17.0       18.0      0.944  ...                0.241
# 8465      0.379      11.0       18.0      0.611  ...                0.179
# 8466      0.486      12.0       14.0      0.857  ...                0.137
# 8467      0.419      13.0       15.0      0.867  ...                0.284
#
#       orb%_prev_game_team1  drb%_prev_game_team1  trb%_prev_game_team1  \
# 16                    20.0                  69.6                  45.1
# 17                    30.4                  75.0                  52.2
# 18                    25.0                  69.6                  47.8
# 19                    23.4                  69.8                  48.0
# 20                    30.2                  76.6                  52.0
# ...                    ...                   ...                   ...
# 8463                  21.9                  76.2                  52.7
# 8464                  21.6                  84.1                  55.6
# 8465                  17.4                  70.0                  44.8
# 8466                  30.0                  82.6                  55.2
# 8467                  32.5                  69.8                  51.8
#
#       ast%_prev_game_team1  stl%_prev_game_team1  blk%_prev_game_team1  \
# 16                    71.1                   5.1                   5.3
# 17                    54.7                  10.6                  14.1
# 18                    48.9                   6.2                   2.9
# 19                    58.1                   5.8                   8.0
# 20                    50.0                   7.7                  17.2
# ...                    ...                   ...                   ...
# 8463                  70.6                   7.2                   9.4
# 8464                  55.6                   7.2                  21.6
# 8465                  58.3                   6.5                   6.5
# 8466                  69.8                   8.6                  14.5
# 8467                  52.5                   7.5                   8.3
#
#       tov%_prev_game_team1  ortg_prev_game_team1  drtg_prev_game_team1
# 16                    13.6                 112.6                 118.7
# 17                    10.8                 123.6                 115.7
# 18                    15.6                 115.7                 123.6
# 19                    14.4                 110.3                 115.1
# 20                     7.3                 115.1                 110.3
# ...                    ...                   ...                   ...
# 8463                  11.4                 132.2                 143.4
# 8464                  10.3                 121.3                 115.1
# 8465                  11.7                 101.3                 128.2
# 8466                   8.2                 128.2                 101.3
# 8467                  11.6                 113.9                 117.1
#
# [8355 rows x 135 columns]

# %%
exceptions = ['team1', 'winner', 'season', 'date', 'team0', 'team0_encoded', 'team1_encoded']

cols_to_keep = [col for col in df.columns if "_prev_game" in col or col in exceptions]

df_filtered = df[cols_to_keep]

# %%
df['team1_winner'] = df.apply(lambda row: 1 if row['winner'] == row['team1'] else 0, axis=1)
df_filtered['team1_winner'] = df_filtered.apply(lambda row: 1 if row['winner'] == row['team1'] else 0, axis=1)
# Out:
# /var/folders/rd/xg_1cl914sb4d864cq60_8zr0000gn/T/ipykernel_53644/584802485.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['team1_winner'] = df_filtered.apply(lambda row: 1 if row['winner'] == row['team1'] else 0, axis=1)

# %%
df_filtered
# Out:
#      team0 team1 winner  season        date  team0_encoded  team1_encoded  \
# 16     SAC   DAL    SAC    2018  2017-10-20             23             27
# 17     POR   IND    POR    2018  2017-10-20             17              7
# 18     ORL   BRK    BRK    2018  2017-10-20             15              4
# 19     BOS   PHI    BOS    2018  2017-10-20              2              5
# 20     DET   WAS    WAS    2018  2017-10-20              8             14
# ...    ...   ...    ...     ...         ...            ...            ...
# 8463   PHI   PHO    PHO    2024  2024-03-20              5             24
# 8464   UTA   OKC    OKC    2024  2024-03-20             18             16
# 8465   IND   DET    IND    2024  2024-03-20              7              8
# 8466   MIL   BOS    BOS    2024  2024-03-20             10              2
# 8467   LAC   POR    LAC    2024  2024-03-20             22             17
#
#       mp_prev_game_team0  fg_prev_game_team0  fga_prev_game_team0  ...  \
# 16                 240.0                42.0                 88.0  ...
# 17                 240.0                44.0                 90.0  ...
# 18                 240.0                43.0                 90.0  ...
# 19                 240.0                39.0                 91.0  ...
# 20                 240.0                41.0                 96.0  ...
# ...                  ...                 ...                  ...  ...
# 8463               240.0                37.0                 85.0  ...
# 8464               240.0                39.0                 84.0  ...
# 8465               240.0                42.0                 91.0  ...
# 8466               240.0                51.0                 94.0  ...
# 8467               240.0                28.0                 74.0  ...
#
#       orb%_prev_game_team1  drb%_prev_game_team1  trb%_prev_game_team1  \
# 16                    20.0                  69.6                  45.1
# 17                    30.4                  75.0                  52.2
# 18                    25.0                  69.6                  47.8
# 19                    23.4                  69.8                  48.0
# 20                    30.2                  76.6                  52.0
# ...                    ...                   ...                   ...
# 8463                  21.9                  76.2                  52.7
# 8464                  21.6                  84.1                  55.6
# 8465                  17.4                  70.0                  44.8
# 8466                  30.0                  82.6                  55.2
# 8467                  32.5                  69.8                  51.8
#
#       ast%_prev_game_team1  stl%_prev_game_team1  blk%_prev_game_team1  \
# 16                    71.1                   5.1                   5.3
# 17                    54.7                  10.6                  14.1
# 18                    48.9                   6.2                   2.9
# 19                    58.1                   5.8                   8.0
# 20                    50.0                   7.7                  17.2
# ...                    ...                   ...                   ...
# 8463                  70.6                   7.2                   9.4
# 8464                  55.6                   7.2                  21.6
# 8465                  58.3                   6.5                   6.5
# 8466                  69.8                   8.6                  14.5
# 8467                  52.5                   7.5                   8.3
#
#       tov%_prev_game_team1  ortg_prev_game_team1  drtg_prev_game_team1  \
# 16                    13.6                 112.6                 118.7
# 17                    10.8                 123.6                 115.7
# 18                    15.6                 115.7                 123.6
# 19                    14.4                 110.3                 115.1
# 20                     7.3                 115.1                 110.3
# ...                    ...                   ...                   ...
# 8463                  11.4                 132.2                 143.4
# 8464                  10.3                 121.3                 115.1
# 8465                  11.7                 101.3                 128.2
# 8466                   8.2                 128.2                 101.3
# 8467                  11.6                 113.9                 117.1
#
#       team1_winner
# 16               0
# 17               0
# 18               1
# 19               0
# 20               1
# ...            ...
# 8463             1
# 8464             1
# 8465             0
# 8466             1
# 8467             0
#
# [8355 rows x 72 columns]

# %%
df_filtered.reset_index(drop=True, inplace=True)

# %%
df_filtered
# Out:
#      team0 team1 winner  season        date  team0_encoded  team1_encoded  \
# 0      SAC   DAL    SAC    2018  2017-10-20             23             27
# 1      POR   IND    POR    2018  2017-10-20             17              7
# 2      ORL   BRK    BRK    2018  2017-10-20             15              4
# 3      BOS   PHI    BOS    2018  2017-10-20              2              5
# 4      DET   WAS    WAS    2018  2017-10-20              8             14
# ...    ...   ...    ...     ...         ...            ...            ...
# 8350   PHI   PHO    PHO    2024  2024-03-20              5             24
# 8351   UTA   OKC    OKC    2024  2024-03-20             18             16
# 8352   IND   DET    IND    2024  2024-03-20              7              8
# 8353   MIL   BOS    BOS    2024  2024-03-20             10              2
# 8354   LAC   POR    LAC    2024  2024-03-20             22             17
#
#       mp_prev_game_team0  fg_prev_game_team0  fga_prev_game_team0  ...  \
# 0                  240.0                42.0                 88.0  ...
# 1                  240.0                44.0                 90.0  ...
# 2                  240.0                43.0                 90.0  ...
# 3                  240.0                39.0                 91.0  ...
# 4                  240.0                41.0                 96.0  ...
# ...                  ...                 ...                  ...  ...
# 8350               240.0                37.0                 85.0  ...
# 8351               240.0                39.0                 84.0  ...
# 8352               240.0                42.0                 91.0  ...
# 8353               240.0                51.0                 94.0  ...
# 8354               240.0                28.0                 74.0  ...
#
#       orb%_prev_game_team1  drb%_prev_game_team1  trb%_prev_game_team1  \
# 0                     20.0                  69.6                  45.1
# 1                     30.4                  75.0                  52.2
# 2                     25.0                  69.6                  47.8
# 3                     23.4                  69.8                  48.0
# 4                     30.2                  76.6                  52.0
# ...                    ...                   ...                   ...
# 8350                  21.9                  76.2                  52.7
# 8351                  21.6                  84.1                  55.6
# 8352                  17.4                  70.0                  44.8
# 8353                  30.0                  82.6                  55.2
# 8354                  32.5                  69.8                  51.8
#
#       ast%_prev_game_team1  stl%_prev_game_team1  blk%_prev_game_team1  \
# 0                     71.1                   5.1                   5.3
# 1                     54.7                  10.6                  14.1
# 2                     48.9                   6.2                   2.9
# 3                     58.1                   5.8                   8.0
# 4                     50.0                   7.7                  17.2
# ...                    ...                   ...                   ...
# 8350                  70.6                   7.2                   9.4
# 8351                  55.6                   7.2                  21.6
# 8352                  58.3                   6.5                   6.5
# 8353                  69.8                   8.6                  14.5
# 8354                  52.5                   7.5                   8.3
#
#       tov%_prev_game_team1  ortg_prev_game_team1  drtg_prev_game_team1  \
# 0                     13.6                 112.6                 118.7
# 1                     10.8                 123.6                 115.7
# 2                     15.6                 115.7                 123.6
# 3                     14.4                 110.3                 115.1
# 4                      7.3                 115.1                 110.3
# ...                    ...                   ...                   ...
# 8350                  11.4                 132.2                 143.4
# 8351                  10.3                 121.3                 115.1
# 8352                  11.7                 101.3                 128.2
# 8353                   8.2                 128.2                 101.3
# 8354                  11.6                 113.9                 117.1
#
#       team1_winner
# 0                0
# 1                0
# 2                1
# 3                0
# 4                1
# ...            ...
# 8350             1
# 8351             1
# 8352             0
# 8353             1
# 8354             0
#
# [8355 rows x 72 columns]

# %%
save_df(df_filtered, "prev_game_df.csv")
