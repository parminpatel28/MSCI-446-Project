# %% [markdown]
# # Feature Engineering – Rolling Average Dataframe
#
# The purpose of this notebook is to create the rolling average dataframe. As mentioned in our presentation, This dataframe averages statistics over the last 5 or 10 games (configure the window_size variable) for each team to capture short-term performance trends. We will be using an iterative approach to loop over every row in the dataframe and accordingly calculate the new values for every column. A hashmap will be leveraged to maintain each team's statistics.

# %%
import pandas as pd
from helper_functions import get_master_df, save_df, drop_extraneous_col

# %% [markdown]
# ### Begin Feature Engineering with Master DF

# %%
df = get_master_df()
drop_extraneous_col(df)

# %%
df.columns
# Out:
# Index(['mp_team0', 'fg_team0', 'fga_team0', 'fg%_team0', '3p_team0',
#        '3pa_team0', '3p%_team0', 'ft_team0', 'fta_team0', 'ft%_team0',
#        'orb_team0', 'drb_team0', 'trb_team0', 'ast_team0', 'stl_team0',
#        'blk_team0', 'tov_team0', 'pf_team0', 'pts_team0', 'ts%_team0',
#        'efg%_team0', '3par_team0', 'ftr_team0', 'orb%_team0', 'drb%_team0',
#        'trb%_team0', 'ast%_team0', 'stl%_team0', 'blk%_team0', 'tov%_team0',
#        'ortg_team0', 'drtg_team0', 'ft/fga_team0', 'team0', 'mp_team1',
#        'fg_team1', 'fga_team1', 'fg%_team1', '3p_team1', '3pa_team1',
#        '3p%_team1', 'ft_team1', 'fta_team1', 'ft%_team1', 'orb_team1',
#        'drb_team1', 'trb_team1', 'ast_team1', 'stl_team1', 'blk_team1',
#        'tov_team1', 'pf_team1', 'pts_team1', 'ts%_team1', 'efg%_team1',
#        '3par_team1', 'ftr_team1', 'orb%_team1', 'drb%_team1', 'trb%_team1',
#        'ast%_team1', 'stl%_team1', 'blk%_team1', 'tov%_team1', 'ortg_team1',
#        'drtg_team1', 'ft/fga_team1', 'team1', 'winner', 'season', 'date',
#        'team0_encoded', 'team1_encoded', 'restDays_team0', 'restDays_team1'],
#       dtype='object')

# %% [markdown]
# ### Team Encoding Object to Create Hashmap

# %%
team_encoding = { 
    # ATLANTIC
    "TOR": 1,
    "BOS": 2,
    "NYK": 3, 
    "BRK": 4,
    "PHI": 5,

    # CENTRAL
    "CLE": 6,
    "IND": 7,
    "DET": 8,
    "CHI": 9,
    "MIL": 10,

    # SOUTHEAST
    "MIA": 11,
    "ATL": 12,
    "CHO": 13,
    "WAS": 14,
    "ORL": 15,

    # NORTHWEST
    "OKC": 16,
    "POR": 17,
    "UTA": 18,
    "DEN": 19,
    "MIN": 20,

    # PACIFIC
    "GSW": 21, 
    "LAC": 22,
    "SAC": 23,
    "PHO": 24,
    "LAL": 25,

    # SOUTH WEST
    "SAS": 26,
    "DAL": 27,
    "MEM": 28,
    "HOU": 29,
    "NOP": 30
}

# %% [markdown]
# ### Variables Required while Constructing New Columns

# %%
unique_stats = [col.split("_")[0] + "_rolling" for col in df.columns if "_team0" in col and "restDays" not in col]
stats = [col.split("_")[0] for col in df.columns if "_team0" in col and "restDays" not in col]
teams = team_encoding.keys()

unique_stats
# Out:
# ['mp_rolling',
#  'fg_rolling',
#  'fga_rolling',
#  'fg%_rolling',
#  '3p_rolling',
#  '3pa_rolling',
#  '3p%_rolling',
#  'ft_rolling',
#  'fta_rolling',
#  'ft%_rolling',
#  'orb_rolling',
#  'drb_rolling',
#  'trb_rolling',
#  'ast_rolling',
#  'stl_rolling',
#  'blk_rolling',
#  'tov_rolling',
#  'pf_rolling',
#  'pts_rolling',
#  'ts%_rolling',
#  'efg%_rolling',
#  '3par_rolling',
#  'ftr_rolling',
#  'orb%_rolling',
#  'drb%_rolling',
#  'trb%_rolling',
#  'ast%_rolling',
#  'stl%_rolling',
#  'blk%_rolling',
#  'tov%_rolling',
#  'ortg_rolling',
#  'drtg_rolling',
#  'ft/fga_rolling']

# %% [markdown]
# ### Leveraging Hashmaps
#
# While we iterate through each row in the dataframe, we will be using a hashmap to keep track of each team's statistics.

# %%
from collections import defaultdict, deque

def initialize_rolling_average(window_size):
    return defaultdict(lambda: defaultdict(lambda: deque(maxlen=window_size)))

# %% [markdown]
# ### Initialize New Columns

# %%
for stat in unique_stats:
    df[f'{stat}_team0'] = 0.0
    df[f'{stat}_team1'] = 0.0

# %% [markdown]
# ### Begin filling New Columns with Data
#
# To change the rolling_average window size, simply change the value in line 1 of the next code block. We set it to 5 and 10 to create both of our dataframes.

# %%
window_size = 5 # previously set to 10

rolling_averages = initialize_rolling_average(window_size)
current_season = None

first_game_indices = set()

for index, row in df.iterrows():
    team0 = row['team0']
    team1 = row['team1']
    game_season = row['season']

    if game_season != current_season:
        rolling_averages = initialize_rolling_average(window_size)
        current_season = game_season

    games_played_team0 = len(rolling_averages[team0]['games_played'])
    games_played_team1 = len(rolling_averages[team1]['games_played'])

    if games_played_team0 < window_size:
        first_game_indices.add(index)

    if games_played_team1 < window_size:
        first_game_indices.add(index)

    for stat in unique_stats:
        if games_played_team0 >= window_size:
            rolling_avg_team0 = sum(rolling_averages[team0][stat]) / window_size
            df.at[index, f"{stat}_team0"] = rolling_avg_team0
        if games_played_team1 >= window_size:
            rolling_avg_team1 = sum(rolling_averages[team1][stat]) / window_size
            df.at[index, f"{stat}_team1"] = rolling_avg_team1

    for stat in stats:
        rolling_averages[team0][f"{stat}_rolling"].append(row[f"{stat}_team0"])
        rolling_averages[team1][f"{stat}_rolling"].append(row[f"{stat}_team1"])

    # Update games played
    rolling_averages[team0]['games_played'].append(1)
    rolling_averages[team1]['games_played'].append(1)

    if index % 100 == 0:
        print(f"{index} / {len(df)}")
# Out:
# 0 / 8468
# 100 / 8468
# 200 / 8468
# 300 / 8468
# 400 / 8468
# 500 / 8468
# 600 / 8468
# 700 / 8468
# 800 / 8468
# 900 / 8468
# 1000 / 8468
# 1100 / 8468
# 1200 / 8468
# 1300 / 8468
# 1400 / 8468
# 1500 / 8468
# 1600 / 8468
# 1700 / 8468
# 1800 / 8468
# 1900 / 8468
# 2000 / 8468
# 2100 / 8468
# 2200 / 8468
# 2300 / 8468
# 2400 / 8468
# 2500 / 8468
# 2600 / 8468
# 2700 / 8468
# 2800 / 8468
# 2900 / 8468
# 3000 / 8468
# 3100 / 8468
# 3200 / 8468
# 3300 / 8468
# 3400 / 8468
# 3500 / 8468
# 3600 / 8468
# 3700 / 8468
# 3800 / 8468
# 3900 / 8468
# 4000 / 8468
# 4100 / 8468
# 4200 / 8468
# 4300 / 8468
# 4400 / 8468
# 4500 / 8468
# 4600 / 8468
# 4700 / 8468
# 4800 / 8468
# 4900 / 8468
# 5000 / 8468
# 5100 / 8468
# 5200 / 8468
# 5300 / 8468
# 5400 / 8468
# 5500 / 8468
# 5600 / 8468
# 5700 / 8468
# 5800 / 8468
# 5900 / 8468
# 6000 / 8468
# 6100 / 8468
# 6200 / 8468
# 6300 / 8468
# 6400 / 8468
# 6500 / 8468
# 6600 / 8468
# 6700 / 8468
# 6800 / 8468
# 6900 / 8468
# 7000 / 8468
# 7100 / 8468
# 7200 / 8468
# 7300 / 8468
# 7400 / 8468
# 7500 / 8468
# 7600 / 8468
# 7700 / 8468
# 7800 / 8468
# 7900 / 8468
# 8000 / 8468
# 8100 / 8468
# 8200 / 8468
# 8300 / 8468
# 8400 / 8468
# defaultdict(<function __main__.initialize_rolling_average.<locals>.<lambda>()>,
#             {'LAL': defaultdict(<function __main__.initialize_rolling_average.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {'games_played': deque([1, 1, 1, 1, 1], maxlen=5),
#                           'mp_rolling': deque([240.0,
#                                  240.0,
#                                  240.0,
#                                  240.0,
#                                  240.0],
#                                 maxlen=5),
#                           'fg_rolling': deque([47.0, 44.0, 38.0, 47.0, 52.0],
#                                 maxlen=5),
#                           'fga_rolling': deque([90.0, 83.0, 78.0, 92.0, 90.0],
#                                 maxlen=5),
#                           'fg%_rolling': deque([0.522,
#                                  0.53,
#                                  0.487,
#                                  0.511,
#                                  0.578],
#                                 maxlen=5),
#                           '3p_rolling': deque([16.0, 10.0, 14.0, 12.0, 15.0],
#                                 maxlen=5),
#                           '3pa_rolling': deque([34.0, 24.0, 32.0, 34.0, 36.0],
#                                 maxlen=5),
#                           '3p%_rolling': deque([0.471,
#                                  0.417,
#                                  0.438,
#                                  0.353,
#                                  0.417],
#                                 maxlen=5),
#                           'ft_rolling': deque([13.0, 22.0, 17.0, 15.0, 17.0],
#                                 maxlen=5),
#                           'fta_rolling': deque([19.0, 29.0, 22.0, 18.0, 20.0],
#                                 maxlen=5),
#                           'ft%_rolling': deque([0.684,
#                                  0.759,
#                                  0.773,
#                                  0.833,
#                                  0.85],
#                                 maxlen=5),
#                           'orb_rolling': deque([4.0, 14.0, 7.0, 8.0, 4.0],
#                                 maxlen=5),
#                           'drb_rolling': deque([34.0, 42.0, 31.0, 31.0, 44.0],
#                                 maxlen=5),
#                           'trb_rolling': deque([38.0, 56.0, 38.0, 39.0, 48.0],
#                                 maxlen=5),
#                           'ast_rolling': deque([27.0, 29.0, 25.0, 32.0, 39.0],
#                                 maxlen=5),
#                           'stl_rolling': deque([2.0, 9.0, 8.0, 3.0, 6.0],
#                                 maxlen=5),
#                           'blk_rolling': deque([7.0, 4.0, 2.0, 4.0, 4.0],
#                                 maxlen=5),
#                           'tov_rolling': deque([5.0, 19.0, 14.0, 9.0, 8.0],
#                                 maxlen=5),
#                           'pf_rolling': deque([16.0, 12.0, 12.0, 13.0, 15.0],
#                                 maxlen=5),
#                           'pts_rolling': deque([123.0,
#                                  120.0,
#                                  107.0,
#                                  121.0,
#                                  136.0],
#                                 maxlen=5),
#                           'ts%_rolling': deque([0.625,
#                                  0.627,
#                                  0.61,
#                                  0.605,
#                                  0.688],
#                                 maxlen=5),
#                           'efg%_rolling': deque([0.611,
#                                  0.59,
#                                  0.577,
#                                  0.576,
#                                  0.661],
#                                 maxlen=5),
#                           '3par_rolling': deque([0.378,
#                                  0.289,
#                                  0.41,
#                                  0.37,
#                                  0.4],
#                                 maxlen=5),
#                           'ftr_rolling': deque([0.211,
#                                  0.349,
#                                  0.282,
#                                  0.196,
#                                  0.222],
#                                 maxlen=5),
#                           'orb%_rolling': deque([9.8, 34.1, 16.7, 20.5, 11.8],
#                                 maxlen=5),
#                           'drb%_rolling': deque([85.0, 79.2, 77.5, 68.9, 78.6],
#                                 maxlen=5),
#                           'trb%_rolling': deque([46.9, 59.6, 46.3, 46.4, 53.3],
#                                 maxlen=5),
#                           'ast%_rolling': deque([57.4, 65.9, 65.8, 68.1, 75.0],
#                                 maxlen=5),
#                           'stl%_rolling': deque([2.0, 9.0, 8.5, 3.1, 6.0],
#                                 maxlen=5),
#                           'blk%_rolling': deque([13.5, 7.8, 4.3, 6.3, 7.0],
#                                 maxlen=5),
#                           'tov%_rolling': deque([4.8, 16.6, 13.8, 8.3, 7.5],
#                                 maxlen=5),
#                           'ortg_rolling': deque([125.3,
#                                  119.9,
#                                  113.6,
#                                  125.4,
#                                  135.1],
#                                 maxlen=5),
#                           'drtg_rolling': deque([124.3,
#                                  108.9,
#                                  127.4,
#                                  132.6,
#                                  104.3],
#                                 maxlen=5),
#                           'ft/fga_rolling': deque([0.144,
#                                  0.265,
#                                  0.218,
#                                  0.163,
#                                  0.189],
#                                 maxlen=5)}),
#              'DEN': defaultdict(<function __main__.initialize_rolling_average.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {'games_played': deque([1, 1, 1, 1, 1], maxlen=5),
#                           'mp_rolling': deque([240.0,
#                                  240.0,
#                                  240.0,
#                                  240.0,
#                                  240.0],
#                                 maxlen=5),
#                           'fg_rolling': deque([52.0, 40.0, 49.0, 37.0, 42.0],
#                                 maxlen=5),
#                           'fga_rolling': deque([95.0, 82.0, 89.0, 84.0, 81.0],
#                                 maxlen=5),
#                           'fg%_rolling': deque([0.547,
#                                  0.488,
#                                  0.551,
#                                  0.44,
#                                  0.519],
#                                 maxlen=5),
#                           '3p_rolling': deque([10.0, 11.0, 10.0, 12.0, 14.0],
#                                 maxlen=5),
#                           '3pa_rolling': deque([29.0, 33.0, 25.0, 28.0, 27.0],
#                                 maxlen=5),
#                           '3p%_rolling': deque([0.345,
#                                  0.333,
#                                  0.4,
#                                  0.429,
#                                  0.519],
#                                 maxlen=5),
#                           'ft_rolling': deque([11.0, 9.0, 9.0, 19.0, 17.0],
#                                 maxlen=5),
#                           'fta_rolling': deque([18.0, 13.0, 12.0, 22.0, 22.0],
#                                 maxlen=5),
#                           'ft%_rolling': deque([0.611,
#                                  0.692,
#                                  0.75,
#                                  0.864,
#                                  0.773],
#                                 maxlen=5),
#                           'orb_rolling': deque([11.0, 7.0, 7.0, 6.0, 11.0],
#                                 maxlen=5),
#                           'drb_rolling': deque([31.0, 34.0, 33.0, 31.0, 38.0],
#                                 maxlen=5),
#                           'trb_rolling': deque([42.0, 41.0, 40.0, 37.0, 49.0],
#                                 maxlen=5),
#                           'ast_rolling': deque([36.0, 24.0, 37.0, 26.0, 26.0],
#                                 maxlen=5),
#                           'stl_rolling': deque([8.0, 4.0, 13.0, 7.0, 5.0],
#                                 maxlen=5),
#                           'blk_rolling': deque([8.0, 2.0, 5.0, 6.0, 1.0],
#                                 maxlen=5),
#                           'tov_rolling': deque([9.0, 9.0, 12.0, 7.0, 17.0],
#                                 maxlen=5),
#                           'pf_rolling': deque([14.0, 13.0, 20.0, 16.0, 19.0],
#                                 maxlen=5),
#                           'pts_rolling': deque([125.0,
#                                  100.0,
#                                  117.0,
#                                  105.0,
#                                  115.0],
#                                 maxlen=5),
#                           'ts%_rolling': deque([0.607,
#                                  0.57,
#                                  0.62,
#                                  0.56,
#                                  0.634],
#                                 maxlen=5),
#                           'efg%_rolling': deque([0.6,
#                                  0.555,
#                                  0.607,
#                                  0.512,
#                                  0.605],
#                                 maxlen=5),
#                           '3par_rolling': deque([0.305,
#                                  0.402,
#                                  0.281,
#                                  0.333,
#                                  0.333],
#                                 maxlen=5),
#                           'ftr_rolling': deque([0.189,
#                                  0.159,
#                                  0.135,
#                                  0.262,
#                                  0.272],
#                                 maxlen=5),
#                           'orb%_rolling': deque([26.2, 17.1, 17.9, 13.6, 27.5],
#                                 maxlen=5),
#                           'drb%_rolling': deque([73.8, 81.0, 73.3, 58.5, 82.6],
#                                 maxlen=5),
#                           'trb%_rolling': deque([50.0, 49.4, 47.6, 38.1, 57.0],
#                                 maxlen=5),
#                           'ast%_rolling': deque([69.2, 60.0, 75.5, 70.3, 61.9],
#                                 maxlen=5),
#                           'stl%_rolling': deque([8.1, 4.6, 13.4, 7.5, 5.2],
#                                 maxlen=5),
#                           'blk%_rolling': deque([12.7, 3.4, 9.6, 9.2, 1.9],
#                                 maxlen=5),
#                           'tov%_rolling': deque([8.0, 9.3, 11.3, 7.0, 15.8],
#                                 maxlen=5),
#                           'ortg_rolling': deque([126.9,
#                                  114.7,
#                                  121.0,
#                                  112.6,
#                                  120.4],
#                                 maxlen=5),
#                           'drtg_rolling': deque([120.8,
#                                  100.9,
#                                  109.6,
#                                  114.7,
#                                  117.3],
#                                 maxlen=5),
#                           'ft/fga_rolling': deque([0.116,
#                                  0.11,
#                                  0.101,
#                                  0.226,
#                                  0.21],
#                                 maxlen=5)}),
#              'PHO': defaultdict(<function __main__.initialize_rolling_average.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {'games_played': deque([1, 1, 1, 1, 1], maxlen=5),
#                           'mp_rolling': deque([240.0,
#                                  240.0,
#                                  240.0,
#                                  240.0,
#                                  240.0],
#                                 maxlen=5),
#                           'fg_rolling': deque([46.0, 47.0, 40.0, 51.0, 45.0],
#                                 maxlen=5),
#                           'fga_rolling': deque([84.0, 99.0, 87.0, 87.0, 90.0],
#                                 maxlen=5),
#                           'fg%_rolling': deque([0.548,
#                                  0.475,
#                                  0.46,
#                                  0.586,
#                                  0.5],
#                                 maxlen=5),
#                           '3p_rolling': deque([12.0, 11.0, 11.0, 14.0, 19.0],
#                                 maxlen=5),
#                           '3pa_rolling': deque([32.0, 31.0, 38.0, 33.0, 39.0],
#                                 maxlen=5),
#                           '3p%_rolling': deque([0.375,
#                                  0.355,
#                                  0.289,
#                                  0.424,
#                                  0.487],
#                                 maxlen=5),
#                           'ft_rolling': deque([13.0, 7.0, 16.0, 13.0, 6.0],
#                                 maxlen=5),
#                           'fta_rolling': deque([19.0, 10.0, 20.0, 15.0, 8.0],
#                                 maxlen=5),
#                           'ft%_rolling': deque([0.684, 0.7, 0.8, 0.867, 0.75],
#                                 maxlen=5),
#                           'orb_rolling': deque([12.0, 19.0, 10.0, 7.0, 14.0],
#                                 maxlen=5),
#                           'drb_rolling': deque([30.0, 32.0, 47.0, 32.0, 41.0],
#                                 maxlen=5),
#                           'trb_rolling': deque([42.0, 51.0, 57.0, 39.0, 55.0],
#                                 maxlen=5),
#                           'ast_rolling': deque([23.0, 27.0, 31.0, 36.0, 34.0],
#                                 maxlen=5),
#                           'stl_rolling': deque([8.0, 4.0, 3.0, 7.0, 7.0],
#                                 maxlen=5),
#                           'blk_rolling': deque([6.0, 3.0, 3.0, 5.0, 12.0],
#                                 maxlen=5),
#                           'tov_rolling': deque([14.0, 13.0, 10.0, 12.0, 23.0],
#                                 maxlen=5),
#                           'pf_rolling': deque([18.0, 12.0, 20.0, 16.0, 18.0],
#                                 maxlen=5),
#                           'pts_rolling': deque([117.0,
#                                  112.0,
#                                  107.0,
#                                  129.0,
#                                  115.0],
#                                 maxlen=5),
#                           'ts%_rolling': deque([0.633,
#                                  0.542,
#                                  0.558,
#                                  0.689,
#                                  0.615],
#                                 maxlen=5),
#                           'efg%_rolling': deque([0.619,
#                                  0.53,
#                                  0.523,
#                                  0.667,
#                                  0.606],
#                                 maxlen=5),
#                           '3par_rolling': deque([0.381,
#                                  0.313,
#                                  0.437,
#                                  0.379,
#                                  0.433],
#                                 maxlen=5),
#                           'ftr_rolling': deque([0.226,
#                                  0.101,
#                                  0.23,
#                                  0.172,
#                                  0.089],
#                                 maxlen=5),
#                           'orb%_rolling': deque([30.8, 41.3, 21.7, 21.9, 34.1],
#                                 maxlen=5),
#                           'drb%_rolling': deque([75.0, 84.2, 79.7, 76.2, 75.9],
#                                 maxlen=5),
#                           'trb%_rolling': deque([53.2, 60.7, 54.3, 52.7, 57.9],
#                                 maxlen=5),
#                           'ast%_rolling': deque([50.0, 57.4, 77.5, 70.6, 75.6],
#                                 maxlen=5),
#                           'stl%_rolling': deque([8.7, 4.3, 3.2, 7.2, 7.1],
#                                 maxlen=5),
#                           'blk%_rolling': deque([15.8, 7.7, 5.3, 9.4, 20.7],
#                                 maxlen=5),
#                           'tov%_rolling': deque([13.2, 11.2, 9.5, 11.4, 19.7],
#                                 maxlen=5),
#                           'ortg_rolling': deque([126.5,
#                                  119.6,
#                                  112.6,
#                                  132.2,
#                                  116.7],
#                                 maxlen=5),
#                           'drtg_rolling': deque([120.1,
#                                  135.6,
#                                  101.0,
#                                  143.4,
#                                  103.5],
#                                 maxlen=5),
#                           'ft/fga_rolling': deque([0.155,
#                                  0.071,
#                                  0.184,
#                                  0.149,
#                                  0.067],
#                                 maxlen=5)}),
#              'GSW': defaultdict(<function __main__.initialize_rolling_average.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {'games_played': deque([1, 1, 1, 1, 1], maxlen=5),
#                           'mp_rolling': deque([240.0,
#                                  240.0,
#                                  240.0,
#                                  240.0,
#                                  240.0],
#                                 maxlen=5),
#                           'fg_rolling': deque([46.0, 37.0, 51.0, 42.0, 58.0],
#                                 maxlen=5),
#                           'fga_rolling': deque([93.0, 92.0, 97.0, 88.0, 100.0],
#                                 maxlen=5),
#                           'fg%_rolling': deque([0.495,
#                                  0.402,
#                                  0.526,
#                                  0.477,
#                                  0.58],
#                                 maxlen=5),
#                           '3p_rolling': deque([12.0, 9.0, 14.0, 14.0, 19.0],
#                                 maxlen=5),
#                           '3pa_rolling': deque([27.0, 28.0, 34.0, 36.0, 39.0],
#                                 maxlen=5),
#                           '3p%_rolling': deque([0.444,
#                                  0.321,
#                                  0.412,
#                                  0.389,
#                                  0.487],
#                                 maxlen=5),
#                           'ft_rolling': deque([8.0, 16.0, 12.0, 14.0, 2.0],
#                                 maxlen=5),
#                           'fta_rolling': deque([12.0, 19.0, 15.0, 18.0, 6.0],
#                                 maxlen=5),
#                           'ft%_rolling': deque([0.667,
#                                  0.842,
#                                  0.8,
#                                  0.778,
#                                  0.333],
#                                 maxlen=5),
#                           'orb_rolling': deque([10.0, 15.0, 14.0, 12.0, 13.0],
#                                 maxlen=5),
#                           'drb_rolling': deque([35.0, 27.0, 31.0, 27.0, 35.0],
#                                 maxlen=5),
#                           'trb_rolling': deque([45.0, 42.0, 45.0, 39.0, 48.0],
#                                 maxlen=5),
#                           'ast_rolling': deque([28.0, 19.0, 38.0, 29.0, 43.0],
#                                 maxlen=5),
#                           'stl_rolling': deque([7.0, 9.0, 3.0, 7.0, 6.0],
#                                 maxlen=5),
#                           'blk_rolling': deque([4.0, 3.0, 4.0, 5.0, 5.0],
#                                 maxlen=5),
#                           'tov_rolling': deque([13.0, 15.0, 7.0, 13.0, 6.0],
#                                 maxlen=5),
#                           'pf_rolling': deque([19.0, 20.0, 19.0, 16.0, 17.0],
#                                 maxlen=5),
#                           'pts_rolling': deque([112.0,
#                                  99.0,
#                                  128.0,
#                                  112.0,
#                                  137.0],
#                                 maxlen=5),
#                           'ts%_rolling': deque([0.57,
#                                  0.493,
#                                  0.618,
#                                  0.584,
#                                  0.667],
#                                 maxlen=5),
#                           'efg%_rolling': deque([0.559,
#                                  0.451,
#                                  0.598,
#                                  0.557,
#                                  0.675],
#                                 maxlen=5),
#                           '3par_rolling': deque([0.29,
#                                  0.304,
#                                  0.351,
#                                  0.409,
#                                  0.39],
#                                 maxlen=5),
#                           'ftr_rolling': deque([0.129,
#                                  0.207,
#                                  0.155,
#                                  0.205,
#                                  0.06],
#                                 maxlen=5),
#                           'orb%_rolling': deque([21.3, 31.3, 31.1, 28.6, 31.0],
#                                 maxlen=5),
#                           'drb%_rolling': deque([72.9, 75.0, 79.5, 65.9, 68.6],
#                                 maxlen=5),
#                           'trb%_rolling': deque([47.4, 50.0, 53.6, 47.0, 51.6],
#                                 maxlen=5),
#                           'ast%_rolling': deque([60.9, 51.4, 74.5, 69.0, 74.1],
#                                 maxlen=5),
#                           'stl%_rolling': deque([7.1, 9.4, 3.1, 7.5, 6.3],
#                                 maxlen=5),
#                           'blk%_rolling': deque([7.1, 5.5, 6.9, 9.3, 10.6],
#                                 maxlen=5),
#                           'tov%_rolling': deque([11.7, 13.0, 6.3, 11.9, 5.5],
#                                 maxlen=5),
#                           'ortg_rolling': deque([112.9,
#                                  103.3,
#                                  132.6,
#                                  120.5,
#                                  144.5],
#                                 maxlen=5),
#                           'drtg_rolling': deque([102.8,
#                                  113.8,
#                                  125.4,
#                                  128.0,
#                                  122.4],
#                                 maxlen=5),
#                           'ft/fga_rolling': deque([0.086,
#                                  0.174,
#                                  0.124,
#                                  0.159,
#                                  0.02],
#                                 maxlen=5)}),
#              'HOU': defaultdict(<function __main__.initialize_rolling_average.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {'games_played': deque([1, 1, 1, 1, 1], maxlen=5),
#                           'mp_rolling': deque([240.0,
#                                  240.0,
#                                  240.0,
#                                  240.0,
#                                  240.0],
#                                 maxlen=5),
#                           'fg_rolling': deque([39.0, 37.0, 51.0, 47.0, 47.0],
#                                 maxlen=5),
#                           'fga_rolling': deque([84.0, 80.0, 87.0, 98.0, 91.0],
#                                 maxlen=5),
#                           'fg%_rolling': deque([0.464,
#                                  0.463,
#                                  0.586,
#                                  0.48,
#                                  0.516],
#                                 maxlen=5),
#                           '3p_rolling': deque([12.0, 10.0, 12.0, 15.0, 13.0],
#                                 maxlen=5),
#                           '3pa_rolling': deque([29.0, 32.0, 28.0, 42.0, 39.0],
#                                 maxlen=5),
#                           '3p%_rolling': deque([0.414,
#                                  0.313,
#                                  0.429,
#                                  0.357,
#                                  0.333],
#                                 maxlen=5),
#                           'ft_rolling': deque([22.0, 19.0, 21.0, 8.0, 30.0],
#                                 maxlen=5),
#                           'fta_rolling': deque([27.0, 21.0, 24.0, 12.0, 36.0],
#                                 maxlen=5),
#                           'ft%_rolling': deque([0.815,
#                                  0.905,
#                                  0.875,
#                                  0.667,
#                                  0.833],
#                                 maxlen=5),
#                           'orb_rolling': deque([6.0, 8.0, 8.0, 11.0, 12.0],
#                                 maxlen=5),
#                           'drb_rolling': deque([36.0, 28.0, 39.0, 37.0, 35.0],
#                                 maxlen=5),
#                           'trb_rolling': deque([42.0, 36.0, 47.0, 48.0, 47.0],
#                                 maxlen=5),
#                           'ast_rolling': deque([23.0, 21.0, 24.0, 28.0, 25.0],
#                                 maxlen=5),
#                           'stl_rolling': deque([8.0, 10.0, 7.0, 9.0, 6.0],
#                                 maxlen=5),
#                           'blk_rolling': deque([1.0, 5.0, 1.0, 7.0, 11.0],
#                                 maxlen=5),
#                           'tov_rolling': deque([12.0, 12.0, 17.0, 9.0, 7.0],
#                                 maxlen=5),
#                           'pf_rolling': deque([18.0, 19.0, 19.0, 19.0, 15.0],
#                                 maxlen=5),
#                           'pts_rolling': deque([112.0,
#                                  103.0,
#                                  135.0,
#                                  117.0,
#                                  137.0],
#                                 maxlen=5),
#                           'ts%_rolling': deque([0.584,
#                                  0.577,
#                                  0.692,
#                                  0.566,
#                                  0.641],
#                                 maxlen=5),
#                           'efg%_rolling': deque([0.536,
#                                  0.525,
#                                  0.655,
#                                  0.556,
#                                  0.588],
#                                 maxlen=5),
#                           '3par_rolling': deque([0.345,
#                                  0.4,
#                                  0.322,
#                                  0.429,
#                                  0.429],
#                                 maxlen=5),
#                           'ftr_rolling': deque([0.321,
#                                  0.263,
#                                  0.276,
#                                  0.122,
#                                  0.396],
#                                 maxlen=5),
#                           'orb%_rolling': deque([14.0, 20.0, 24.2, 22.4, 30.8],
#                                 maxlen=5),
#                           'drb%_rolling': deque([83.7, 73.7, 84.8, 84.1, 67.3],
#                                 maxlen=5),
#                           'trb%_rolling': deque([48.8, 46.2, 59.5, 51.6, 51.6],
#                                 maxlen=5),
#                           'ast%_rolling': deque([59.0, 56.8, 47.1, 59.6, 53.2],
#                                 maxlen=5),
#                           'stl%_rolling': deque([8.0, 11.1, 6.7, 9.1, 6.2],
#                                 maxlen=5),
#                           'blk%_rolling': deque([1.9, 10.9, 1.8, 15.9, 18.6],
#                                 maxlen=5),
#                           'tov%_rolling': deque([11.1, 11.9, 14.8, 8.0, 6.1],
#                                 maxlen=5),
#                           'ortg_rolling': deque([112.5,
#                                  114.6,
#                                  128.4,
#                                  118.8,
#                                  141.0],
#                                 maxlen=5),
#                           'drtg_rolling': deque([104.5,
#                                  112.4,
#                                  113.2,
#                                  104.6,
#                                  117.3],
#                                 maxlen=5),
#                           'ft/fga_rolling': deque([0.262,
#                                  0.238,
#                                  0.241,
#                                  0.082,
#                                  0.33],
#                                 maxlen=5)}),
#              'ORL': defaultdict(<function __main__.initialize_rolling_average.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {'games_played': deque([1, 1, 1, 1, 1], maxlen=5),
#                           'mp_rolling': deque([240.0,
#                                  240.0,
#                                  240.0,
#                                  240.0,
#                                  240.0],
#                                 maxlen=5),
#                           'fg_rolling': deque([33.0, 40.0, 40.0, 43.0, 44.0],
#                                 maxlen=5),
#                           'fga_rolling': deque([88.0, 77.0, 80.0, 85.0, 81.0],
#                                 maxlen=5),
#                           'fg%_rolling': deque([0.375,
#                                  0.519,
#                                  0.5,
#                                  0.506,
#                                  0.543],
#                                 maxlen=5),
#                           '3p_rolling': deque([9.0, 14.0, 14.0, 11.0, 12.0],
#                                 maxlen=5),
#                           '3pa_rolling': deque([36.0, 32.0, 31.0, 36.0, 34.0],
#                                 maxlen=5),
#                           '3p%_rolling': deque([0.25,
#                                  0.438,
#                                  0.452,
#                                  0.306,
#                                  0.353],
#                                 maxlen=5),
#                           'ft_rolling': deque([22.0, 20.0, 19.0, 14.0, 12.0],
#                                 maxlen=5),
#                           'fta_rolling': deque([29.0, 26.0, 22.0, 20.0, 13.0],
#                                 maxlen=5),
#                           'ft%_rolling': deque([0.759,
#                                  0.769,
#                                  0.864,
#                                  0.7,
#                                  0.923],
#                                 maxlen=5),
#                           'orb_rolling': deque([13.0, 6.0, 6.0, 10.0, 10.0],
#                                 maxlen=5),
#                           'drb_rolling': deque([33.0, 28.0, 33.0, 29.0, 31.0],
#                                 maxlen=5),
#                           'trb_rolling': deque([46.0, 34.0, 39.0, 39.0, 41.0],
#                                 maxlen=5),
#                           'ast_rolling': deque([18.0, 29.0, 25.0, 22.0, 32.0],
#                                 maxlen=5),
#                           'stl_rolling': deque([7.0, 6.0, 7.0, 7.0, 10.0],
#                                 maxlen=5),
#                           'blk_rolling': deque([3.0, 6.0, 4.0, 4.0, 6.0],
#                                 maxlen=5),
#                           'tov_rolling': deque([12.0, 12.0, 14.0, 13.0, 16.0],
#                                 maxlen=5),
#                           'pf_rolling': deque([27.0, 20.0, 15.0, 16.0, 10.0],
#                                 maxlen=5),
#                           'pts_rolling': deque([97.0,
#                                  114.0,
#                                  113.0,
#                                  111.0,
#                                  112.0],
#                                 maxlen=5),
#                           'ts%_rolling': deque([0.481,
#                                  0.645,
#                                  0.63,
#                                  0.592,
#                                  0.646],
#                                 maxlen=5),
#                           'efg%_rolling': deque([0.426,
#                                  0.61,
#                                  0.588,
#                                  0.571,
#                                  0.617],
#                                 maxlen=5),
#                           '3par_rolling': deque([0.409,
#                                  0.416,
#                                  0.388,
#                                  0.424,
#                                  0.42],
#                                 maxlen=5),
#                           'ftr_rolling': deque([0.33,
#                                  0.338,
#                                  0.275,
#                                  0.235,
#                                  0.16],
#                                 maxlen=5),
#                           'orb%_rolling': deque([24.1, 20.0, 16.2, 27.8, 27.8],
#                                 maxlen=5),
#                           'drb%_rolling': deque([86.8, 77.8, 78.6, 72.5, 88.6],
#                                 maxlen=5),
#                           'trb%_rolling': deque([50.0, 51.5, 49.4, 51.3, 57.7],
#                                 maxlen=5),
#                           'ast%_rolling': deque([54.5, 72.5, 62.5, 51.2, 72.7],
#                                 maxlen=5),
#                           'stl%_rolling': deque([7.2, 6.4, 7.4, 7.5, 10.8],
#                                 maxlen=5),
#                           'blk%_rolling': deque([5.5, 10.9, 8.5, 7.5, 12.0],
#                                 maxlen=5),
#                           'tov%_rolling': deque([10.6, 11.9, 13.5, 12.2, 15.6],
#                                 maxlen=5),
#                           'ortg_rolling': deque([99.5,
#                                  122.5,
#                                  118.9,
#                                  118.3,
#                                  120.6],
#                                 maxlen=5),
#                           'drtg_rolling': deque([113.8,
#                                  113.9,
#                                  108.4,
#                                  102.3,
#                                  99.0],
#                                 maxlen=5),
#                           'ft/fga_rolling': deque([0.25,
#                                  0.26,
#                                  0.238,
#                                  0.165,
#                                  0.148],
#                                 maxlen=5)}),
#              'POR': defaultdict(<function __main__.initialize_rolling_average.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {'games_played': deque([1, 1, 1, 1, 1], maxlen=5),
#                           'mp_rolling': deque([240.0,
#                                  240.0,
#                                  240.0,
#                                  240.0,
#                                  240.0],
#                                 maxlen=5),
#                           'fg_rolling': deque([38.0, 34.0, 42.0, 40.0, 39.0],
#                                 maxlen=5),
#                           'fga_rolling': deque([82.0, 84.0, 84.0, 88.0, 81.0],
#                                 maxlen=5),
#                           'fg%_rolling': deque([0.463,
#                                  0.405,
#                                  0.5,
#                                  0.455,
#                                  0.481],
#                                 maxlen=5),
#                           '3p_rolling': deque([10.0, 11.0, 12.0, 8.0, 15.0],
#                                 maxlen=5),
#                           '3pa_rolling': deque([30.0, 33.0, 33.0, 28.0, 34.0],
#                                 maxlen=5),
#                           '3p%_rolling': deque([0.333,
#                                  0.333,
#                                  0.364,
#                                  0.286,
#                                  0.441],
#                                 maxlen=5),
#                           'ft_rolling': deque([20.0, 14.0, 11.0, 19.0, 10.0],
#                                 maxlen=5),
#                           'fta_rolling': deque([24.0, 16.0, 12.0, 25.0, 15.0],
#                                 maxlen=5),
#                           'ft%_rolling': deque([0.833,
#                                  0.875,
#                                  0.917,
#                                  0.76,
#                                  0.667],
#                                 maxlen=5),
#                           'orb_rolling': deque([12.0, 13.0, 10.0, 13.0, 8.0],
#                                 maxlen=5),
#                           'drb_rolling': deque([37.0, 32.0, 26.0, 30.0, 30.0],
#                                 maxlen=5),
#                           'trb_rolling': deque([49.0, 45.0, 36.0, 43.0, 38.0],
#                                 maxlen=5),
#                           'ast_rolling': deque([24.0, 19.0, 23.0, 21.0, 21.0],
#                                 maxlen=5),
#                           'stl_rolling': deque([7.0, 10.0, 3.0, 7.0, 6.0],
#                                 maxlen=5),
#                           'blk_rolling': deque([5.0, 2.0, 7.0, 5.0, 4.0],
#                                 maxlen=5),
#                           'tov_rolling': deque([18.0, 17.0, 19.0, 13.0, 17.0],
#                                 maxlen=5),
#                           'pf_rolling': deque([21.0, 19.0, 15.0, 24.0, 16.0],
#                                 maxlen=5),
#                           'pts_rolling': deque([106.0,
#                                  93.0,
#                                  107.0,
#                                  107.0,
#                                  103.0],
#                                 maxlen=5),
#                           'ts%_rolling': deque([0.573,
#                                  0.511,
#                                  0.599,
#                                  0.54,
#                                  0.588],
#                                 maxlen=5),
#                           'efg%_rolling': deque([0.524,
#                                  0.47,
#                                  0.571,
#                                  0.5,
#                                  0.574],
#                                 maxlen=5),
#                           '3par_rolling': deque([0.366,
#                                  0.393,
#                                  0.393,
#                                  0.318,
#                                  0.42],
#                                 maxlen=5),
#                           'ftr_rolling': deque([0.293,
#                                  0.19,
#                                  0.143,
#                                  0.284,
#                                  0.185],
#                                 maxlen=5),
#                           'orb%_rolling': deque([32.4, 27.1, 25.6, 32.5, 19.0],
#                                 maxlen=5),
#                           'drb%_rolling': deque([74.0, 68.1, 72.2, 69.8, 78.9],
#                                 maxlen=5),
#                           'trb%_rolling': deque([56.3, 47.4, 48.0, 51.8, 47.5],
#                                 maxlen=5),
#                           'ast%_rolling': deque([63.2, 55.9, 54.8, 52.5, 53.8],
#                                 maxlen=5),
#                           'stl%_rolling': deque([7.4, 10.8, 3.1, 7.5, 6.3],
#                                 maxlen=5),
#                           'blk%_rolling': deque([10.2, 3.4, 10.9, 8.3, 7.3],
#                                 maxlen=5),
#                           'tov%_rolling': deque([16.3, 15.7, 17.5, 11.6, 16.3],
#                                 maxlen=5),
#                           'ortg_rolling': deque([111.8,
#                                  100.2,
#                                  110.9,
#                                  113.9,
#                                  108.9],
#                                 maxlen=5),
#                           'drtg_rolling': deque([107.6,
#                                  113.2,
#                                  130.6,
#                                  117.1,
#                                  122.6],
#                                 maxlen=5),
#                           'ft/fga_rolling': deque([0.244,
#                                  0.167,
#                                  0.131,
#                                  0.216,
#                                  0.123],
#                                 maxlen=5)}),
#              'LAC': defaultdict(<function __main__.initialize_rolling_average.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {'games_played': deque([1, 1, 1, 1, 1], maxlen=5),
#                           'mp_rolling': deque([240.0,
#                                  240.0,
#                                  240.0,
#                                  240.0,
#                                  240.0],
#                                 maxlen=5),
#                           'fg_rolling': deque([34.0, 48.0, 37.0, 28.0, 45.0],
#                                 maxlen=5),
#                           'fga_rolling': deque([72.0, 80.0, 77.0, 74.0, 86.0],
#                                 maxlen=5),
#                           'fg%_rolling': deque([0.472,
#                                  0.6,
#                                  0.481,
#                                  0.378,
#                                  0.523],
#                                 maxlen=5),
#                           '3p_rolling': deque([11.0, 20.0, 12.0, 11.0, 13.0],
#                                 maxlen=5),
#                           '3pa_rolling': deque([30.0, 40.0, 33.0, 36.0, 31.0],
#                                 maxlen=5),
#                           '3p%_rolling': deque([0.367,
#                                  0.5,
#                                  0.364,
#                                  0.306,
#                                  0.419],
#                                 maxlen=5),
#                           'ft_rolling': deque([21.0, 10.0, 18.0, 26.0, 13.0],
#                                 maxlen=5),
#                           'fta_rolling': deque([25.0, 14.0, 19.0, 29.0, 15.0],
#                                 maxlen=5),
#                           'ft%_rolling': deque([0.84,
#                                  0.714,
#                                  0.947,
#                                  0.897,
#                                  0.867],
#                                 maxlen=5),
#                           'orb_rolling': deque([8.0, 6.0, 5.0, 10.0, 8.0],
#                                 maxlen=5),
#                           'drb_rolling': deque([26.0, 29.0, 32.0, 30.0, 34.0],
#                                 maxlen=5),
#                           'trb_rolling': deque([34.0, 35.0, 37.0, 40.0, 42.0],
#                                 maxlen=5),
#                           'ast_rolling': deque([22.0, 32.0, 18.0, 17.0, 29.0],
#                                 maxlen=5),
#                           'stl_rolling': deque([7.0, 9.0, 6.0, 10.0, 15.0],
#                                 maxlen=5),
#                           'blk_rolling': deque([4.0, 2.0, 8.0, 5.0, 7.0],
#                                 maxlen=5),
#                           'tov_rolling': deque([18.0, 9.0, 12.0, 15.0, 11.0],
#                                 maxlen=5),
#                           'pf_rolling': deque([18.0, 16.0, 17.0, 13.0, 13.0],
#                                 maxlen=5),
#                           'pts_rolling': deque([100.0,
#                                  126.0,
#                                  104.0,
#                                  93.0,
#                                  116.0],
#                                 maxlen=5),
#                           'ts%_rolling': deque([0.602,
#                                  0.731,
#                                  0.609,
#                                  0.536,
#                                  0.626],
#                                 maxlen=5),
#                           'efg%_rolling': deque([0.549,
#                                  0.725,
#                                  0.558,
#                                  0.453,
#                                  0.599],
#                                 maxlen=5),
#                           '3par_rolling': deque([0.417,
#                                  0.5,
#                                  0.429,
#                                  0.486,
#                                  0.36],
#                                 maxlen=5),
#                           'ftr_rolling': deque([0.347,
#                                  0.175,
#                                  0.247,
#                                  0.392,
#                                  0.174],
#                                 maxlen=5),
#                           'orb%_rolling': deque([21.6, 19.4, 13.9, 22.2, 21.1],
#                                 maxlen=5),
#                           'drb%_rolling': deque([57.8, 72.5, 78.0, 75.0, 81.0],
#                                 maxlen=5),
#                           'trb%_rolling': deque([41.5, 49.3, 48.1, 47.1, 52.5],
#                                 maxlen=5),
#                           'ast%_rolling': deque([64.7, 66.7, 48.6, 60.7, 64.4],
#                                 maxlen=5),
#                           'stl%_rolling': deque([7.8, 10.0, 6.6, 11.1, 15.9],
#                                 maxlen=5),
#                           'blk%_rolling': deque([6.6, 3.9, 15.4, 10.0, 14.9],
#                                 maxlen=5),
#                           'tov%_rolling': deque([17.8, 9.5, 12.3, 14.7, 10.6],
#                                 maxlen=5),
#                           'ortg_rolling': deque([111.7,
#                                  139.9,
#                                  113.6,
#                                  102.8,
#                                  122.6],
#                                 maxlen=5),
#                           'drtg_rolling': deque([131.8,
#                                  123.2,
#                                  122.3,
#                                  121.6,
#                                  108.9],
#                                 maxlen=5),
#                           'ft/fga_rolling': deque([0.292,
#                                  0.125,
#                                  0.234,
#                                  0.351,
#                                  0.151],
#                                 maxlen=5)}),
#              'OKC': defaultdict(<function __main__.initialize_rolling_average.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {'games_played': deque([1, 1, 1, 1, 1], maxlen=5),
#                           'mp_rolling': deque([240.0,
#                                  240.0,
# ...
#                                  0.444,
#                                  0.585,
#                                  0.486],
#                                 maxlen=5),
#                           'ft_rolling': deque([21.0, 27.0, 20.0, 14.0, 12.0],
#                                 maxlen=5),
#                           'fta_rolling': deque([27.0, 35.0, 24.0, 14.0, 14.0],
#                                 maxlen=5),
#                           'ft%_rolling': deque([0.778,
#                                  0.771,
#                                  0.833,
#                                  1.0,
#                                  0.857],
#                                 maxlen=5),
#                           'orb_rolling': deque([7.0, 10.0, 6.0, 10.0, 9.0],
#                                 maxlen=5),
#                           'drb_rolling': deque([34.0, 34.0, 31.0, 25.0, 32.0],
#                                 maxlen=5),
#                           'trb_rolling': deque([41.0, 44.0, 37.0, 35.0, 41.0],
#                                 maxlen=5),
#                           'ast_rolling': deque([28.0, 23.0, 29.0, 35.0, 20.0],
#                                 maxlen=5),
#                           'stl_rolling': deque([5.0, 3.0, 6.0, 11.0, 3.0],
#                                 maxlen=5),
#                           'blk_rolling': deque([6.0, 2.0, 4.0, 2.0, 6.0],
#                                 maxlen=5),
#                           'tov_rolling': deque([7.0, 13.0, 14.0, 10.0, 14.0],
#                                 maxlen=5),
#                           'pf_rolling': deque([15.0, 18.0, 14.0, 12.0, 25.0],
#                                 maxlen=5),
#                           'pts_rolling': deque([124.0,
#                                  94.0,
#                                  114.0,
#                                  140.0,
#                                  119.0],
#                                 maxlen=5),
#                           'ts%_rolling': deque([0.627,
#                                  0.483,
#                                  0.69,
#                                  0.699,
#                                  0.66],
#                                 maxlen=5),
#                           'efg%_rolling': deque([0.592,
#                                  0.409,
#                                  0.653,
#                                  0.67,
#                                  0.637],
#                                 maxlen=5),
#                           '3par_rolling': deque([0.437,
#                                  0.476,
#                                  0.5,
#                                  0.436,
#                                  0.417],
#                                 maxlen=5),
#                           'ftr_rolling': deque([0.31,
#                                  0.427,
#                                  0.333,
#                                  0.149,
#                                  0.167],
#                                 maxlen=5),
#                           'orb%_rolling': deque([16.7, 18.2, 20.0, 23.8, 25.7],
#                                 maxlen=5),
#                           'drb%_rolling': deque([66.7, 85.0, 83.8, 78.1, 74.4],
#                                 maxlen=5),
#                           'trb%_rolling': deque([44.1, 46.3, 55.2, 47.3, 52.6],
#                                 maxlen=5),
#                           'ast%_rolling': deque([65.1, 76.7, 74.4, 68.6, 44.4],
#                                 maxlen=5),
#                           'stl%_rolling': deque([5.1, 3.0, 6.8, 11.3, 3.2],
#                                 maxlen=5),
#                           'blk%_rolling': deque([10.5, 3.8, 9.1, 3.7, 13.3],
#                                 maxlen=5),
#                           'tov%_rolling': deque([6.6, 11.8, 14.5, 9.1, 13.4],
#                                 maxlen=5),
#                           'ortg_rolling': deque([127.4,
#                                  94.8,
#                                  128.7,
#                                  143.4,
#                                  127.9],
#                                 maxlen=5),
#                           'drtg_rolling': deque([120.2,
#                                  130.1,
#                                  118.5,
#                                  132.2,
#                                  131.1],
#                                 maxlen=5),
#                           'ft/fga_rolling': deque([0.241,
#                                  0.329,
#                                  0.278,
#                                  0.149,
#                                  0.143],
#                                 maxlen=5)}),
#              'CHO': defaultdict(<function __main__.initialize_rolling_average.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {'games_played': deque([1, 1, 1, 1, 1], maxlen=5),
#                           'mp_rolling': deque([240.0,
#                                  240.0,
#                                  240.0,
#                                  240.0,
#                                  240.0],
#                                 maxlen=5),
#                           'fg_rolling': deque([34.0, 44.0, 35.0, 37.0, 38.0],
#                                 maxlen=5),
#                           'fga_rolling': deque([88.0, 82.0, 94.0, 82.0, 79.0],
#                                 maxlen=5),
#                           'fg%_rolling': deque([0.386,
#                                  0.537,
#                                  0.372,
#                                  0.451,
#                                  0.481],
#                                 maxlen=5),
#                           '3p_rolling': deque([13.0, 13.0, 6.0, 10.0, 9.0],
#                                 maxlen=5),
#                           '3pa_rolling': deque([40.0, 36.0, 37.0, 31.0, 29.0],
#                                 maxlen=5),
#                           '3p%_rolling': deque([0.325,
#                                  0.361,
#                                  0.162,
#                                  0.323,
#                                  0.31],
#                                 maxlen=5),
#                           'ft_rolling': deque([16.0, 9.0, 20.0, 14.0, 7.0],
#                                 maxlen=5),
#                           'fta_rolling': deque([23.0, 13.0, 27.0, 18.0, 9.0],
#                                 maxlen=5),
#                           'ft%_rolling': deque([0.696,
#                                  0.692,
#                                  0.741,
#                                  0.778,
#                                  0.778],
#                                 maxlen=5),
#                           'orb_rolling': deque([9.0, 6.0, 12.0, 12.0, 4.0],
#                                 maxlen=5),
#                           'drb_rolling': deque([31.0, 29.0, 36.0, 28.0, 26.0],
#                                 maxlen=5),
#                           'trb_rolling': deque([40.0, 35.0, 48.0, 40.0, 30.0],
#                                 maxlen=5),
#                           'ast_rolling': deque([27.0, 26.0, 20.0, 21.0, 19.0],
#                                 maxlen=5),
#                           'stl_rolling': deque([7.0, 12.0, 6.0, 11.0, 8.0],
#                                 maxlen=5),
#                           'blk_rolling': deque([2.0, 7.0, 3.0, 4.0, 1.0],
#                                 maxlen=5),
#                           'tov_rolling': deque([12.0, 20.0, 4.0, 16.0, 17.0],
#                                 maxlen=5),
#                           'pf_rolling': deque([16.0, 11.0, 16.0, 21.0, 13.0],
#                                 maxlen=5),
#                           'pts_rolling': deque([97.0, 110.0, 96.0, 98.0, 92.0],
#                                 maxlen=5),
#                           'ts%_rolling': deque([0.494,
#                                  0.627,
#                                  0.453,
#                                  0.545,
#                                  0.554],
#                                 maxlen=5),
#                           'efg%_rolling': deque([0.46,
#                                  0.616,
#                                  0.404,
#                                  0.512,
#                                  0.538],
#                                 maxlen=5),
#                           '3par_rolling': deque([0.455,
#                                  0.439,
#                                  0.394,
#                                  0.378,
#                                  0.367],
#                                 maxlen=5),
#                           'ftr_rolling': deque([0.261,
#                                  0.159,
#                                  0.287,
#                                  0.22,
#                                  0.114],
#                                 maxlen=5),
#                           'orb%_rolling': deque([17.6, 16.7, 20.3, 27.9, 11.4],
#                                 maxlen=5),
#                           'drb%_rolling': deque([77.5, 64.4, 78.3, 73.7, 72.2],
#                                 maxlen=5),
#                           'trb%_rolling': deque([44.0, 43.2, 45.7, 49.4, 42.3],
#                                 maxlen=5),
#                           'ast%_rolling': deque([79.4, 59.1, 57.1, 56.8, 50.0],
#                                 maxlen=5),
#                           'stl%_rolling': deque([7.2, 12.5, 6.3, 11.9, 8.6],
#                                 maxlen=5),
#                           'blk%_rolling': deque([4.5, 15.6, 6.1, 10.0, 2.1],
#                                 maxlen=5),
#                           'tov%_rolling': deque([10.9, 18.6, 3.6, 15.1, 17.0],
#                                 maxlen=5),
#                           'ortg_rolling': deque([99.1,
#                                  114.5,
#                                  101.0,
#                                  105.9,
#                                  99.0],
#                                 maxlen=5),
#                           'drtg_rolling': deque([116.5,
#                                  102.0,
#                                  112.6,
#                                  117.8,
#                                  120.6],
#                                 maxlen=5),
#                           'ft/fga_rolling': deque([0.182,
#                                  0.11,
#                                  0.213,
#                                  0.171,
#                                  0.089],
#                                 maxlen=5)}),
#              'ATL': defaultdict(<function __main__.initialize_rolling_average.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {'games_played': deque([1, 1, 1, 1, 1], maxlen=5),
#                           'mp_rolling': deque([240.0,
#                                  240.0,
#                                  240.0,
#                                  240.0,
#                                  240.0],
#                                 maxlen=5),
#                           'fg_rolling': deque([38.0, 38.0, 41.0, 41.0, 42.0],
#                                 maxlen=5),
#                           'fga_rolling': deque([91.0, 88.0, 92.0, 84.0, 98.0],
#                                 maxlen=5),
#                           'fg%_rolling': deque([0.418,
#                                  0.432,
#                                  0.446,
#                                  0.488,
#                                  0.429],
#                                 maxlen=5),
#                           '3p_rolling': deque([17.0, 14.0, 20.0, 17.0, 9.0],
#                                 maxlen=5),
#                           '3pa_rolling': deque([46.0, 39.0, 39.0, 34.0, 41.0],
#                                 maxlen=5),
#                           '3p%_rolling': deque([0.37, 0.359, 0.513, 0.5, 0.22],
#                                 maxlen=5),
#                           'ft_rolling': deque([10.0, 12.0, 20.0, 11.0, 12.0],
#                                 maxlen=5),
#                           'fta_rolling': deque([13.0, 18.0, 27.0, 12.0, 15.0],
#                                 maxlen=5),
#                           'ft%_rolling': deque([0.769,
#                                  0.667,
#                                  0.741,
#                                  0.917,
#                                  0.8],
#                                 maxlen=5),
#                           'orb_rolling': deque([12.0, 13.0, 11.0, 10.0, 12.0],
#                                 maxlen=5),
#                           'drb_rolling': deque([29.0, 25.0, 30.0, 35.0, 30.0],
#                                 maxlen=5),
#                           'trb_rolling': deque([41.0, 38.0, 41.0, 45.0, 42.0],
#                                 maxlen=5),
#                           'ast_rolling': deque([28.0, 19.0, 32.0, 32.0, 32.0],
#                                 maxlen=5),
#                           'stl_rolling': deque([6.0, 11.0, 7.0, 10.0, 8.0],
#                                 maxlen=5),
#                           'blk_rolling': deque([4.0, 6.0, 5.0, 7.0, 5.0],
#                                 maxlen=5),
#                           'tov_rolling': deque([11.0, 14.0, 9.0, 14.0, 9.0],
#                                 maxlen=5),
#                           'pf_rolling': deque([15.0, 23.0, 16.0, 22.0, 14.0],
#                                 maxlen=5),
#                           'pts_rolling': deque([103.0,
#                                  102.0,
#                                  122.0,
#                                  110.0,
#                                  105.0],
#                                 maxlen=5),
#                           'ts%_rolling': deque([0.532,
#                                  0.532,
#                                  0.587,
#                                  0.616,
#                                  0.502],
#                                 maxlen=5),
#                           'efg%_rolling': deque([0.511,
#                                  0.511,
#                                  0.554,
#                                  0.589,
#                                  0.474],
#                                 maxlen=5),
#                           '3par_rolling': deque([0.505,
#                                  0.443,
#                                  0.424,
#                                  0.405,
#                                  0.418],
#                                 maxlen=5),
#                           'ftr_rolling': deque([0.143,
#                                  0.205,
#                                  0.293,
#                                  0.143,
#                                  0.153],
#                                 maxlen=5),
#                           'orb%_rolling': deque([23.5, 26.0, 22.0, 25.0, 21.4],
#                                 maxlen=5),
#                           'drb%_rolling': deque([87.9, 67.6, 75.0, 77.8, 88.2],
#                                 maxlen=5),
#                           'trb%_rolling': deque([48.8, 43.7, 45.6, 52.9, 46.7],
#                                 maxlen=5),
#                           'ast%_rolling': deque([73.7, 50.0, 78.0, 78.0, 76.2],
#                                 maxlen=5),
#                           'stl%_rolling': deque([6.5, 11.6, 7.1, 11.1, 7.9],
#                                 maxlen=5),
#                           'blk%_rolling': deque([8.3, 11.5, 9.3, 18.4, 9.3],
#                                 maxlen=5),
#                           'tov%_rolling': deque([10.2, 12.7, 8.0, 13.6, 7.9],
#                                 maxlen=5),
#                           'ortg_rolling': deque([111.0,
#                                  107.6,
#                                  123.8,
#                                  121.6,
#                                  104.3],
#                                 maxlen=5),
#                           'drtg_rolling': deque([125.1,
#                                  111.8,
#                                  125.9,
#                                  102.8,
#                                  135.1],
#                                 maxlen=5),
#                           'ft/fga_rolling': deque([0.11,
#                                  0.136,
#                                  0.217,
#                                  0.131,
#                                  0.122],
#                                 maxlen=5)})})

# %% [markdown]
# ### Dropping Rows
#
# For each team's first 5/10 games of each season, we need to drop its row. This is because there is no data we can use to predict the outcome of the game. Although we could use previous season stats, teams generally change quite a bit between each season. As a result, we made the decision to simply drop these rows.

# %%
first_game_indices
df = df.drop(first_game_indices)

# %%
df
# Out:
#       mp_team0  fg_team0  fga_team0  fg%_team0  3p_team0  3pa_team0  \
# 76       240.0      29.0       77.0      0.377      14.0       38.0
# 78       240.0      36.0       78.0      0.462      12.0       32.0
# 79       240.0      37.0       87.0      0.425       9.0       26.0
# 80       240.0      43.0       87.0      0.494      16.0       35.0
# 83       240.0      36.0       90.0      0.400       9.0       28.0
# ...        ...       ...        ...        ...       ...        ...
# 8463     240.0      45.0       84.0      0.536      17.0       35.0
# 8464     240.0      41.0       95.0      0.432      13.0       37.0
# 8465     240.0      38.0       83.0      0.458      13.0       36.0
# 8466     240.0      45.0       86.0      0.523      13.0       31.0
# 8467     240.0      42.0       96.0      0.438      18.0       49.0
#
#       3p%_team0  ft_team0  fta_team0  ft%_team0  ...  blk%_rolling_team0  \
# 76        0.368      17.0       21.0      0.810  ...                9.54
# 78        0.375      17.0       23.0      0.739  ...                9.32
# 79        0.346      24.0       30.0      0.800  ...                9.28
# 80        0.457      10.0       14.0      0.714  ...                8.72
# 83        0.321      13.0       18.0      0.722  ...               13.78
# ...         ...       ...        ...        ...  ...                 ...
# 8463      0.486      12.0       14.0      0.857  ...                6.14
# 8464      0.351       7.0       18.0      0.389  ...               12.62
# 8465      0.361      18.0       19.0      0.947  ...                8.36
# 8466      0.419      13.0       15.0      0.867  ...               10.86
# 8467      0.367      14.0       18.0      0.778  ...               10.88
#
#       blk%_rolling_team1  tov%_rolling_team0  tov%_rolling_team1  \
# 76                  8.56               14.62               13.88
# 78                 10.30               14.56               14.98
# 79                 10.88               15.82               11.82
# 80                  5.68               15.42               11.76
# 83                  6.66               12.78               12.66
# ...                  ...                 ...                 ...
# 8463               12.90                9.52                7.76
# 8464                8.00               11.72               11.66
# 8465                7.20                9.82               12.02
# 8466                8.22               12.54               14.36
# 8467                8.40               14.20               10.70
#
#       ortg_rolling_team0  ortg_rolling_team1  drtg_rolling_team0  \
# 76                107.76              106.94              101.62
# 78                111.52              106.46              110.56
# 79                 97.08              115.18              113.24
# 80                 99.38              100.78              106.62
# 83                104.44              111.82              101.60
# ...                  ...                 ...                 ...
# 8463              123.72              133.44              125.26
# 8464              104.76              120.48              107.80
# 8465              106.04              115.26              107.38
# 8466              117.64              109.26              125.26
# 8467              106.36              116.68              115.98
#
#       drtg_rolling_team1  ft/fga_rolling_team0  ft/fga_rolling_team1
# 76                101.52                0.2350                0.3258
# 78                109.54                0.2222                0.2284
# 79                100.62                0.2390                0.2568
# 80                110.18                0.1702                0.2058
# 83                113.66                0.2076                0.2278
# ...                  ...                   ...                   ...
# 8463              111.12                0.2296                0.1402
# 8464              124.40                0.1580                0.1348
# 8465              118.06                0.1430                0.1680
# 8466              120.46                0.2178                0.1768
# 8467              119.44                0.2044                0.1564
#
# [7908 rows x 141 columns]

# %% [markdown]
# ### Add Back Columns
#
# Certain columns listed in 'exceptions' cannot be averaged throughout the season. As a result, they are added back into the dataframe once the feature engineering is completed.

# %%
exceptions = ['team1', 'winner', 'season', 'date', 'team0', 'team0_encoded', 'team1_encoded', 'restDays_team0', 'restDays_team1']

cols_to_keep = [col for col in df.columns if "rolling" in col or col in exceptions]

df_filtered = df[cols_to_keep]

# %% [markdown]
# ### Determine Team 1 Winner
#
# As mentioned in our presentation, each dataframe possesses a column relating to team1_winner. This will have a value of 1 if team1 wins and a value of 0 if team1 loses.

# %%
df['team1_winner'] = df.apply(lambda row: 1 if row['winner'] == row['team1'] else 0, axis=1)
df_filtered['team1_winner'] = df_filtered.apply(lambda row: 1 if row['winner'] == row['team1'] else 0, axis=1)
# Out:
# /var/folders/rd/xg_1cl914sb4d864cq60_8zr0000gn/T/ipykernel_90856/584802485.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['team1_winner'] = df_filtered.apply(lambda row: 1 if row['winner'] == row['team1'] else 0, axis=1)

# %%
df_filtered
# Out:
#      team0 team1 winner  season       date  team0_encoded  team1_encoded  \
# 76     HOU   MEM    MEM    2018 2017-10-28             29             28
# 78     CLE   NOP    NOP    2018 2017-10-28              6             30
# 79     PHO   POR    POR    2018 2017-10-28             24             17
# 80     PHI   DAL    PHI    2018 2017-10-28              5             27
# 83     SAS   IND    IND    2018 2017-10-29             26              7
# ...    ...   ...    ...     ...        ...            ...            ...
# 8463   MIL   BOS    BOS    2024 2024-03-20             10              2
# 8464   PHI   PHO    PHO    2024 2024-03-20              5             24
# 8465   MIA   CLE    MIA    2024 2024-03-20             11              6
# 8466   LAC   POR    LAC    2024 2024-03-20             22             17
# 8467   MEM   GSW    GSW    2024 2024-03-20             28             21
#
#       restDays_team0  restDays_team1  mp_rolling_team0  ...  \
# 76               0.0             1.0             240.0  ...
# 78               2.0             1.0             240.0  ...
# 79               2.0             1.0             240.0  ...
# 80               2.0             1.0             240.0  ...
# 83               1.0             3.0             240.0  ...
# ...              ...             ...               ...  ...
# 8463             2.0             1.0             240.0  ...
# 8464             1.0             2.0             240.0  ...
# 8465             1.0             1.0             240.0  ...
# 8466             2.0             1.0             240.0  ...
# 8467             1.0             1.0             245.0  ...
#
#       blk%_rolling_team1  tov%_rolling_team0  tov%_rolling_team1  \
# 76                  8.56               14.62               13.88
# 78                 10.30               14.56               14.98
# 79                 10.88               15.82               11.82
# 80                  5.68               15.42               11.76
# 83                  6.66               12.78               12.66
# ...                  ...                 ...                 ...
# 8463               12.90                9.52                7.76
# 8464                8.00               11.72               11.66
# 8465                7.20                9.82               12.02
# 8466                8.22               12.54               14.36
# 8467                8.40               14.20               10.70
#
#       ortg_rolling_team0  ortg_rolling_team1  drtg_rolling_team0  \
# 76                107.76              106.94              101.62
# 78                111.52              106.46              110.56
# 79                 97.08              115.18              113.24
# 80                 99.38              100.78              106.62
# 83                104.44              111.82              101.60
# ...                  ...                 ...                 ...
# 8463              123.72              133.44              125.26
# 8464              104.76              120.48              107.80
# 8465              106.04              115.26              107.38
# 8466              117.64              109.26              125.26
# 8467              106.36              116.68              115.98
#
#       drtg_rolling_team1  ft/fga_rolling_team0  ft/fga_rolling_team1  \
# 76                101.52                0.2350                0.3258
# 78                109.54                0.2222                0.2284
# 79                100.62                0.2390                0.2568
# 80                110.18                0.1702                0.2058
# 83                113.66                0.2076                0.2278
# ...                  ...                   ...                   ...
# 8463              111.12                0.2296                0.1402
# 8464              124.40                0.1580                0.1348
# 8465              118.06                0.1430                0.1680
# 8466              120.46                0.2178                0.1768
# 8467              119.44                0.2044                0.1564
#
#       team1_winner
# 76               1
# 78               1
# 79               1
# 80               0
# 83               1
# ...            ...
# 8463             1
# 8464             1
# 8465             0
# 8466             0
# 8467             1
#
# [7908 rows x 76 columns]

# %%
df_filtered.reset_index(drop=True, inplace=True)

# %%
df_filtered
# Out:
#      team0 team1 winner  season       date  team0_encoded  team1_encoded  \
# 0      HOU   MEM    MEM    2018 2017-10-28             29             28
# 1      CLE   NOP    NOP    2018 2017-10-28              6             30
# 2      PHO   POR    POR    2018 2017-10-28             24             17
# 3      PHI   DAL    PHI    2018 2017-10-28              5             27
# 4      SAS   IND    IND    2018 2017-10-29             26              7
# ...    ...   ...    ...     ...        ...            ...            ...
# 7903   MIL   BOS    BOS    2024 2024-03-20             10              2
# 7904   PHI   PHO    PHO    2024 2024-03-20              5             24
# 7905   MIA   CLE    MIA    2024 2024-03-20             11              6
# 7906   LAC   POR    LAC    2024 2024-03-20             22             17
# 7907   MEM   GSW    GSW    2024 2024-03-20             28             21
#
#       restDays_team0  restDays_team1  mp_rolling_team0  ...  \
# 0                0.0             1.0             240.0  ...
# 1                2.0             1.0             240.0  ...
# 2                2.0             1.0             240.0  ...
# 3                2.0             1.0             240.0  ...
# 4                1.0             3.0             240.0  ...
# ...              ...             ...               ...  ...
# 7903             2.0             1.0             240.0  ...
# 7904             1.0             2.0             240.0  ...
# 7905             1.0             1.0             240.0  ...
# 7906             2.0             1.0             240.0  ...
# 7907             1.0             1.0             245.0  ...
#
#       blk%_rolling_team1  tov%_rolling_team0  tov%_rolling_team1  \
# 0                   8.56               14.62               13.88
# 1                  10.30               14.56               14.98
# 2                  10.88               15.82               11.82
# 3                   5.68               15.42               11.76
# 4                   6.66               12.78               12.66
# ...                  ...                 ...                 ...
# 7903               12.90                9.52                7.76
# 7904                8.00               11.72               11.66
# 7905                7.20                9.82               12.02
# 7906                8.22               12.54               14.36
# 7907                8.40               14.20               10.70
#
#       ortg_rolling_team0  ortg_rolling_team1  drtg_rolling_team0  \
# 0                 107.76              106.94              101.62
# 1                 111.52              106.46              110.56
# 2                  97.08              115.18              113.24
# 3                  99.38              100.78              106.62
# 4                 104.44              111.82              101.60
# ...                  ...                 ...                 ...
# 7903              123.72              133.44              125.26
# 7904              104.76              120.48              107.80
# 7905              106.04              115.26              107.38
# 7906              117.64              109.26              125.26
# 7907              106.36              116.68              115.98
#
#       drtg_rolling_team1  ft/fga_rolling_team0  ft/fga_rolling_team1  \
# 0                 101.52                0.2350                0.3258
# 1                 109.54                0.2222                0.2284
# 2                 100.62                0.2390                0.2568
# 3                 110.18                0.1702                0.2058
# 4                 113.66                0.2076                0.2278
# ...                  ...                   ...                   ...
# 7903              111.12                0.2296                0.1402
# 7904              124.40                0.1580                0.1348
# 7905              118.06                0.1430                0.1680
# 7906              120.46                0.2178                0.1768
# 7907              119.44                0.2044                0.1564
#
#       team1_winner
# 0                1
# 1                1
# 2                1
# 3                0
# 4                1
# ...            ...
# 7903             1
# 7904             1
# 7905             0
# 7906             0
# 7907             1
#
# [7908 rows x 76 columns]

# %%
#save_df(df_filtered, "rolling_average_10_day.csv")
save_df(df_filtered, "rolling_average_5_day.csv")
